# %%
import os
import glob
import math
import nltk
import pandas as pd
from xml.etree import ElementTree as ET
from collections import defaultdict
import re
import string

# %%
def load_stop_words(file_path="common-english-words.txt"): #
    """Load stop words from a comma-separated file."""
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            stop_words = f.read().strip().split(',')
        return set(sw.strip() for sw in stop_words if sw.strip()) # Ensure clean stop words
    except FileNotFoundError:
        print(f"Error: Stop words file '{file_path}' not found. Returning empty set.")
        return set()
    except Exception as e:
        print(f"Error loading stop words from {file_path}: {e}")
        return set()

# %%
def normalize_token(token_text):
    """
    Normalizes a token by converting to lowercase and stripping leading/trailing punctuation.
    Keeps internal punctuation.
    """
    if not token_text:
        return None
    term_lower = token_text.lower()
    # Strip leading and trailing punctuation characters.
    # e.g., "U.S." -> "u.s.", "(word)" -> "word", "word." -> "word"
    normalized = term_lower.strip(string.punctuation)
    # Return the normalized term if it's not empty, otherwise None
    return normalized if normalized else None

# %%
def parse_queries(query_file): #
    """Parse query file to extract query numbers and titles."""
    queries = {}
    try:
        with open(query_file, 'r', encoding='utf-8') as f:
            content = f.read()
            # Split by "<Query>" and handle potential empty string at the beginning
            query_blocks = content.split('<Query>')
            if query_blocks and query_blocks[0].strip() == "":
                query_blocks = query_blocks[1:]

            for block in query_blocks:
                if not block.strip():
                    continue
                num_match = re.search(r'<num>\s*Number:\s*(R\d+)', block) #
                # MODIFIED REGEX FOR TITLE to capture full line content
                title_match = re.search(r'<title>\s*([^\n<]+)', block) 
                
                if num_match and title_match:
                    query_num = num_match.group(1)
                    title = title_match.group(1).strip() #
                    queries[query_num] = title
                else:
                    num_found = "Found" if num_match else "Not Found"
                    title_found = "Found" if title_match else "Not Found"
                    # print(f"Skipping query block: Num: {num_found}, Title: {title_found}. Block: {block[:70]}...")
    except FileNotFoundError:
        print(f"Error: Query file '{query_file}' not found.")
        return {}
    except Exception as e:
        print(f"Error parsing {query_file}: {e}")
        return {}
    return queries

# %%
def parse_dataset(folder, stop_words): #
    """Parse XML documents in a dataset folder into a collection of term frequencies."""
    docs = defaultdict(lambda: defaultdict(int)) # Ensure docs is initialized correctly
    for file_path in glob.glob(os.path.join(folder, "*.xml")):
        try:
            tree = ET.parse(file_path)
            root = tree.getroot()
            # Namespace removal for tags
            for elem in root.iter():
                if '}' in elem.tag:
                    elem.tag = elem.tag.split('}', 1)[1] #
            
            newsitem = root if root.tag == 'newsitem' else root.find(".//newsitem") #
            if newsitem is None:
                # print(f"Skipping {file_path}: No <newsitem> tag found")
                continue
            doc_id = newsitem.get("itemid") #
            if doc_id is None:
                # print(f"Skipping {file_path}: No itemid attribute found")
                continue
            
            text_elements = newsitem.findall(".//text/p") #
            if not text_elements:
                # print(f"Skipping {file_path}: No <text><p> elements found")
                continue
            
            text_content = " ".join([e.text for e in text_elements if e.text]) #
            
            # Using new normalization for document terms
            raw_doc_tokens = nltk.word_tokenize(text_content)
            processed_doc_terms = []
            for token in raw_doc_tokens:
                normalized = normalize_token(token)
                if normalized:
                    processed_doc_terms.append(normalized)
            
            final_doc_terms = [t for t in processed_doc_terms if t not in stop_words] #
            
            # docs[doc_id] = defaultdict(int) # This was in the original, moved up.
            for t in final_doc_terms:
                docs[doc_id][t] += 1
        except ET.ParseError:
            print(f"XML Parse Error in {file_path}. Skipping this file.")
        except Exception as e:
            print(f"Error parsing document {file_path}: {e}")
    return dict(docs) # Convert back to dict for more standard behavior if preferred

# %%
def bm25_score(query_terms, docs, k1=1.2, k2=500, b=0.75): #
    """Calculate BM25 scores for all documents."""
    N = len(docs)
    if N == 0:
        return []
        
    dl = {doc_id: sum(freqs.values()) for doc_id, freqs in docs.items()} #
    avdl = sum(dl.values()) / N #
    if avdl == 0: avdl = 1.0 # Avoid division by zero if all docs are empty

    # Calculate document frequency (n_i) for each term in the entire collection
    doc_freq = defaultdict(int) # n_i: number of docs containing term i
    for doc_content in docs.values():
        for term in set(doc_content.keys()): # Iterate over unique terms in this document
            doc_freq[term] += 1
            
    scores = {}
    query_term_counts = defaultdict(int) # qf_i: frequency of term i in the query
    for term in query_terms:
        query_term_counts[term] += 1

    for doc_id, doc_content in docs.items():
        score = 0.0
        doc_len = dl.get(doc_id, 0)
        K = k1 * ((1 - b) + b * (doc_len / avdl)) #
        
        for term in set(query_terms): # Iterate over unique terms in the query
            if term not in doc_content and term not in doc_freq : # Term not in query, or not in any doc
                 continue

            f_i = doc_content.get(term, 0) # Frequency of term i in the current document D
            qf_i = query_term_counts[term]  # Frequency of term i in the query Q
            n_i = doc_freq.get(term, 0)    # Number of documents containing term i

            # IDF calculation using the formula from the notebook
            # IDF_i = math.log2((N - n_i + 0.5) / (n_i + 0.5) + 1)
            idf_val_num = (N - n_i + 0.5)
            idf_val_den = (n_i + 0.5)
            
            if idf_val_den == 0: # Should not happen if n_i is from doc_freq of existing terms
                idf_component = 0 
            else:
                idf_component = idf_val_num / idf_val_den

            if idf_component < 0: idf_component = 0 # Ensure argument to log is not negative

            IDF_i = math.log2(idf_component + 1) # (Adding 1 before log2)
            
            doc_term_weight = ((k1 + 1) * f_i) / (K + f_i) #
            query_term_weight = ((k2 + 1) * qf_i) / (k2 + qf_i) #
            
            score += IDF_i * doc_term_weight * query_term_weight
            
        scores[doc_id] = score
    return sorted(scores.items(), key=lambda x: x[1], reverse=True) #

# %%
def run_bm25ir(query_file, dataset_base_path, output_folder, stop_words, top12_excel): #
    """Run BM25IR on all datasets and save top-12 results."""
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    all_top12_data = []
    queries = parse_queries(query_file) #
    
    print(f"Total queries parsed: {len(queries)}")
    expected_query_ids = {f"R{num}" for num in range(101, 151)} #
    
    # Process queries in sorted order for consistent output
    for query_num in sorted(list(expected_query_ids)):
        if query_num not in queries:
            print(f"Query {query_num} not found in Queries-1.txt. Skipping.")
            for rank_idx in range(1, 13):
                all_top12_data.append({'Query': query_num, 'Rank': rank_idx, 'Document_ID': 'N/A - Query Missing', 'BM25_Score': 0.0})
            continue

        current_query_title = queries[query_num]
        dataset_folder = os.path.join(dataset_base_path, f"Dataset{query_num[1:]}") #

        if not os.path.exists(dataset_folder):
            print(f"Dataset folder {dataset_folder} not found for Query {query_num}. Skipping.")
            for rank_idx in range(1, 13):
                all_top12_data.append({'Query': query_num, 'Rank': rank_idx, 'Document_ID': 'N/A - Dataset Missing', 'BM25_Score': 0.0})
            continue
        
        print(f"\nProcessing Query {query_num} (Title: '{current_query_title}')")
        print(f"Dataset {dataset_folder}: Found {len(glob.glob(os.path.join(dataset_folder, '*.xml')))} XML files")
        
        docs = parse_dataset(dataset_folder, stop_words) #
        if not docs:
            print(f"No documents parsed for {dataset_folder} (Query {query_num}). Skipping.")
            for rank_idx in range(1, 13):
                all_top12_data.append({'Query': query_num, 'Rank': rank_idx, 'Document_ID': 'N/A - No Docs Parsed', 'BM25_Score': 0.0})
            continue
        print(f"Dataset {dataset_folder}: Parsed {len(docs)} documents.")

        # Using new normalization for query terms
        raw_query_tokens = nltk.word_tokenize(current_query_title)
        processed_query_terms = []
        for token in raw_query_tokens:
            normalized = normalize_token(token)
            if normalized:
                processed_query_terms.append(normalized)
        query_terms = [t for t in processed_query_terms if t not in stop_words] #
        
        print(f"Final query terms for {query_num}: {query_terms}")

        if not query_terms:
            print(f"Query {query_num} has no terms after processing. Skipping ranking.")
            for rank_idx in range(1, 13):
                all_top12_data.append({'Query': query_num, 'Rank': rank_idx, 'Document_ID': 'N/A - No Query Terms', 'BM25_Score': 0.0})
            continue
            
        ranked_docs = bm25_score(query_terms, docs) #
        output_file_path = os.path.join(output_folder, f"BM25IR_{query_num}Ranking.dat") #
        
        with open(output_file_path, "w", encoding="utf-8") as f_out:
            for doc_id, score in ranked_docs:
                f_out.write(f"{doc_id} {score}\n") #
        print(f"Saved rankings for {query_num} to {output_file_path}")
        
        print(f"Top-12 documents for Query_{query_num}:")
        for i, (doc_id, score) in enumerate(ranked_docs[:12]):
            print(f"  Rank {i+1}: {doc_id} (Score: {score:.4f})")
            all_top12_data.append({
                'Query': query_num, 'Rank': i + 1, 'Document_ID': doc_id, 'BM25_Score': score
            })
        
        # Add placeholders if fewer than 12 results were found
        for rank_idx in range(len(ranked_docs) + 1, 13):
            all_top12_data.append({
                'Query': query_num, 'Rank': rank_idx, 'Document_ID': 'N/A - Fewer than 12 results', 'BM25_Score': 0.0
            })

    df_top12 = pd.DataFrame(all_top12_data) #
    df_top12 = df_top12.reindex(columns=['Query', 'Rank', 'Document_ID', 'BM25_Score']) # Ensure column order

    try:
        with pd.ExcelWriter(top12_excel, engine='xlsxwriter') as writer: #
            df_top12.to_excel(writer, sheet_name='BM25IR Top 12', index=False) #
        print(f"\nTop-12 documents for all queries saved to {top12_excel}")
    except Exception as e:
        print(f"Error writing to Excel file {top12_excel}: {e}")
        csv_fallback_path = top12_excel.replace(".xlsx", "_fallback.csv")
        try:
            df_top12.to_csv(csv_fallback_path, index=False)
            print(f"Saved top-12 results to CSV as fallback: {csv_fallback_path}")
        except Exception as e_csv:
            print(f"Error writing to CSV fallback {csv_fallback_path}: {e_csv}")

# %%
# --- Main Execution ---
if __name__ == '__main__': # Good practice to put main execution code here
    QUERY_FILE = "Queries-1.txt" #
    DATASET_BASE_PATH = "DataSets-1" #
    OUTPUT_FOLDER = "BM25RankingOutputs" #
    STOP_WORDS_FILE = "common-english-words.txt" #
    TOP12_EXCEL = "BM25IR_Top12_Results.xlsx" #

    print("Loading stop words...")
    STOP_WORDS = load_stop_words(STOP_WORDS_FILE)
    if not STOP_WORDS:
        print("Warning: No stop words loaded. Proceeding with an empty stop word list.")
    else:
        print(f"Loaded {len(STOP_WORDS)} stop words.")

    print("\nRunning BM25IR System...")
    run_bm25ir(QUERY_FILE, DATASET_BASE_PATH, OUTPUT_FOLDER, STOP_WORDS, TOP12_EXCEL)
    print("\nBM25IR System run complete.")
# Out:
# Loading stop words...
# Loaded 119 stop words.
#
# Running BM25IR System...
# Total queries parsed: 50
#
# Processing Query R101 (Title: 'Economic espionage')
# Dataset DataSets-1\Dataset101: Found 23 XML files
# Dataset DataSets-1\Dataset101: Parsed 23 documents.
# Final query terms for R101: ['economic', 'espionage']
# Saved rankings for R101 to BM25RankingOutputs\BM25IR_R101Ranking.dat
# Top-12 documents for Query_R101:
#   Rank 1: 46547 (Score: 6.3310)
#   Rank 2: 46974 (Score: 6.3310)
#   Rank 3: 62325 (Score: 4.7737)
#   Rank 4: 6146 (Score: 2.7870)
#   Rank 5: 61329 (Score: 2.6003)
#   Rank 6: 22170 (Score: 2.5127)
#   Rank 7: 61780 (Score: 2.2597)
#   Rank 8: 22513 (Score: 1.7784)
#   Rank 9: 82330 (Score: 1.4353)
#   Rank 10: 39496 (Score: 1.1719)
#   Rank 11: 18586 (Score: 0.0000)
#   Rank 12: 26642 (Score: 0.0000)
#
# Processing Query R102 (Title: 'Convicts, repeat offenders')
# Dataset DataSets-1\Dataset102: Found 199 XML files
# Dataset DataSets-1\Dataset102: Parsed 199 documents.
# Final query terms for R102: ['convicts', 'repeat', 'offenders']
# Saved rankings for R102 to BM25RankingOutputs\BM25IR_R102Ranking.dat
# Top-12 documents for Query_R102:
#   Rank 1: 58476 (Score: 16.3916)
#   Rank 2: 26061 (Score: 9.2525)
#   Rank 3: 78836 (Score: 8.4700)
#   Rank 4: 76635 (Score: 8.2423)
#   Rank 5: 12769 (Score: 7.6631)
#   Rank 6: 65414 (Score: 7.5830)
#   Rank 7: 12767 (Score: 7.4234)
#   Rank 8: 82227 (Score: 7.2213)
#   Rank 9: 65036 (Score: 4.6859)
#   Rank 10: 65446 (Score: 4.6165)
#   Rank 11: 64645 (Score: 4.1491)
#   Rank 12: 73038 (Score: 3.7584)
#
# Processing Query R103 (Title: 'Ferry Boat sinkings')
# Dataset DataSets-1\Dataset103: Found 64 XML files
# Dataset DataSets-1\Dataset103: Parsed 64 documents.
# Final query terms for R103: ['ferry', 'boat', 'sinkings']
# Saved rankings for R103 to BM25RankingOutputs\BM25IR_R103Ranking.dat
# Top-12 documents for Query_R103:
#   Rank 1: 26385 (Score: 4.2654)
#   Rank 9: 6386 (Score: 3.4349)
#   Rank 10: 8085 (Score: 2.9552)
#   Rank 11: 31281 (Score: 1.9216)
#   Rank 12: 32963 (Score: 1.9099)
#
# Processing Query R107 (Title: 'Tourism Great Britain')
# Dataset DataSets-1\Dataset107: Found 61 XML files
# Dataset DataSets-1\Dataset107: Parsed 61 documents.
# Final query terms for R107: ['tourism', 'great', 'britain']
# Saved rankings for R107 to BM25RankingOutputs\BM25IR_R107Ranking.dat
# Top-12 documents for Query_R107:
#   Rank 1: 51576 (Score: 8.0224)
#   Rank 2: 77936 (Score: 5.8822)
#   Rank 3: 71157 (Score: 5.7043)
#   Rank 4: 79950 (Score: 5.3692)
#   Rank 5: 59244 (Score: 4.6960)
#   Rank 6: 67107 (Score: 4.2532)
#   Rank 7: 67411 (Score: 4.2532)
#   Rank 8: 86459 (Score: 3.1195)
#   Rank 9: 31404 (Score: 1.1460)
#   Rank 10: 41791 (Score: 1.1146)
#   Rank 11: 69377 (Score: 1.1054)
#   Rank 12: 37330 (Score: 1.0958)
#
# Processing Query R108 (Title: 'Harmful weight-loss drugs')
# Dataset DataSets-1\Dataset108: Found 53 XML files
# Dataset DataSets-1\Dataset108: Parsed 53 documents.
# Final query terms for R108: ['harmful', 'weight-loss', 'drugs']
# Saved rankings for R108 to BM25RankingOutputs\BM25IR_R108Ranking.dat
# Top-12 documents for Query_R108:
#   Rank 1: 2829 (Score: 6.5685)
#   Rank 2: 5176 (Score: 6.0235)
#   Rank 3: 5177 (Score: 6.0235)
#   Rank 4: 10810 (Score: 5.7758)
#   Rank 5: 8780 (Score: 3.6108)
#   Rank 6: 80518 (Score: 2.7829)
#   Rank 7: 22662 (Score: 2.7307)
#   Rank 8: 82392 (Score: 2.3458)
#   Rank 9: 19961 (Score: 2.3027)
#   Rank 10: 78878 (Score: 2.2917)
#   Rank 11: 8938 (Score: 2.2716)
#   Rank 12: 54814 (Score: 2.2545)
#
# Processing Query R109 (Title: 'Child custody cases')
# Dataset DataSets-1\Dataset109: Found 40 XML files
# Dataset DataSets-1\Dataset109: Parsed 40 documents.
# Final query terms for R109: ['child', 'custody', 'cases']
# Saved rankings for R109 to BM25RankingOutputs\BM25IR_R109Ranking.dat
# Top-12 documents for Query_R109:
#   Rank 1: 16953 (Score: 7.9410)
#   Rank 2: 26073 (Score: 6.4157)
#   Rank 3: 29729 (Score: 3.2870)
#   Rank 4: 16575 (Score: 3.0956)
#   Rank 5: 78626 (Score: 2.8998)
#   Rank 6: 82229 (Score: 2.8051)
#   Rank 7: 34684 (Score: 2.7945)
#   Rank 8: 23398 (Score: 2.7331)
#   Rank 9: 56735 (Score: 2.6637)
#   Rank 10: 61540 (Score: 2.6330)
#   Rank 11: 73598 (Score: 2.5775)
#   Rank 12: 4933 (Score: 2.4782)
#
# Processing Query R110 (Title: 'Terrorism Middle East tourism')
# Dataset DataSets-1\Dataset110: Found 91 XML files
# Dataset DataSets-1\Dataset110: Parsed 91 documents.
# Processing Query R117 (Title: 'Organ transplants in the UK')
# Dataset DataSets-1\Dataset117: Found 13 XML files
# Dataset DataSets-1\Dataset117: Parsed 13 documents.
# Final query terms for R117: ['organ', 'transplants', 'uk']
# Saved rankings for R117 to BM25RankingOutputs\BM25IR_R117Ranking.dat
# Top-12 documents for Query_R117:
#   Rank 1: 62586 (Score: 3.9525)
#   Rank 2: 65692 (Score: 3.0545)
#   Rank 3: 71102 (Score: 2.8707)
#   Rank 4: 54844 (Score: 2.8527)
#   Rank 5: 67204 (Score: 2.7692)
#   Rank 6: 9544 (Score: 1.7906)
#   Rank 7: 81694 (Score: 1.3868)
#   Rank 8: 37425 (Score: 1.0534)
#   Rank 9: 21113 (Score: 0.0000)
#   Rank 10: 48566 (Score: 0.0000)
#   Rank 11: 60811 (Score: 0.0000)
#   Rank 12: 74800 (Score: 0.0000)
#
# Processing Query R118 (Title: 'Progress in treatment of schizophrenia')
# Dataset DataSets-1\Dataset118: Found 32 XML files
# Dataset DataSets-1\Dataset118: Parsed 32 documents.
# Final query terms for R118: ['progress', 'treatment', 'schizophrenia']
# Saved rankings for R118 to BM25RankingOutputs\BM25IR_R118Ranking.dat
# Top-12 documents for Query_R118:
#   Rank 1: 80908 (Score: 5.1375)
#   Rank 2: 20763 (Score: 4.8543)
#   Rank 3: 28903 (Score: 4.1880)
#   Rank 4: 43173 (Score: 3.8948)
#   Rank 5: 84529 (Score: 2.9126)
#   Rank 6: 35104 (Score: 2.7143)
#   Rank 7: 47129 (Score: 2.6574)
#   Rank 8: 50269 (Score: 2.5396)
#   Rank 9: 28826 (Score: 2.4617)
#   Rank 10: 43241 (Score: 2.3786)
#   Rank 11: 9544 (Score: 2.3765)
#   Rank 12: 33112 (Score: 1.9524)
#
# Processing Query R119 (Title: 'U.S. gas prices')
# Dataset DataSets-1\Dataset119: Found 26 XML files
# Dataset DataSets-1\Dataset119: Parsed 26 documents.
# Final query terms for R119: ['u.s', 'gas', 'prices']
# Saved rankings for R119 to BM25RankingOutputs\BM25IR_R119Ranking.dat
# Top-12 documents for Query_R119:
#   Rank 1: 34033 (Score: 3.3011)
#   Rank 2: 41275 (Score: 2.9868)
#   Rank 3: 65942 (Score: 2.4449)
#   Rank 4: 51080 (Score: 2.4184)
#   Rank 5: 51082 (Score: 2.4184)
#   Rank 6: 65019 (Score: 2.3107)
#   Rank 7: 68177 (Score: 2.1542)
#   Rank 8: 51488 (Score: 1.6020)
#   Rank 9: 63311 (Score: 0.7854)
#   Rank 10: 26074 (Score: 0.7811)
#   Rank 11: 35105 (Score: 0.7621)
#   Rank 12: 13902 (Score: 0.7043)
#
# Processing Query R120 (Title: 'Deaths mining accidents')
# Dataset DataSets-1\Dataset120: Found 54 XML files
# Dataset DataSets-1\Dataset120: Parsed 54 documents.
# Final query terms for R120: ['deaths', 'mining', 'accidents']
# Saved rankings for R120 to BM25RankingOutputs\BM25IR_R120Ranking.dat
# Top-12 documents for Query_R120:
#   Rank 1: 39184 (Score: 13.3975)
#   Rank 9: 47699 (Score: 2.0039)
#   Rank 10: 2454 (Score: 2.0000)
#   Rank 11: 75032 (Score: 1.9486)
#   Rank 12: 66425 (Score: 1.8641)
#
# Processing Query R124 (Title: 'Aborigine health')
# Dataset DataSets-1\Dataset124: Found 33 XML files
# Dataset DataSets-1\Dataset124: Parsed 33 documents.
# Final query terms for R124: ['aborigine', 'health']
# Saved rankings for R124 to BM25RankingOutputs\BM25IR_R124Ranking.dat
# Top-12 documents for Query_R124:
#   Rank 1: 9981 (Score: 4.0399)
#   Rank 2: 2345 (Score: 3.2521)
#   Rank 3: 2346 (Score: 3.2305)
#   Rank 4: 79951 (Score: 2.6469)
#   Rank 5: 25328 (Score: 2.1368)
#   Rank 6: 21511 (Score: 2.0181)
#   Rank 7: 19285 (Score: 1.9934)
#   Rank 8: 30653 (Score: 1.7024)
#   Rank 9: 65604 (Score: 1.6906)
#   Rank 10: 74036 (Score: 1.6625)
#   Rank 11: 4528 (Score: 1.6064)
#   Rank 12: 7225 (Score: 1.3389)
#
# Processing Query R125 (Title: 'Scottish Independence')
# Dataset DataSets-1\Dataset125: Found 36 XML files
# Dataset DataSets-1\Dataset125: Parsed 36 documents.
# Final query terms for R125: ['scottish', 'independence']
# Saved rankings for R125 to BM25RankingOutputs\BM25IR_R125Ranking.dat
# Top-12 documents for Query_R125:
#   Rank 1: 77907 (Score: 5.5220)
#   Rank 2: 77381 (Score: 5.2472)
#   Rank 3: 82519 (Score: 4.0031)
#   Rank 4: 80922 (Score: 3.7765)
#   Rank 5: 82085 (Score: 3.7337)
#   Rank 6: 9011 (Score: 3.7074)
#   Rank 7: 7970 (Score: 3.6344)
#   Rank 8: 73371 (Score: 1.9806)
#   Rank 9: 25833 (Score: 1.9052)
#   Rank 10: 27974 (Score: 1.8654)
#   Rank 11: 39122 (Score: 1.8307)
#   Rank 12: 27960 (Score: 1.8185)
#
# Processing Query R126 (Title: 'Nuclear plants U.S.')
# Dataset DataSets-1\Dataset126: Found 29 XML files
# Dataset DataSets-1\Dataset126: Parsed 29 documents.
# Final query terms for R126: ['nuclear', 'plants', 'u.s']
# Saved rankings for R126 to BM25RankingOutputs\BM25IR_R126Ranking.dat
# Top-12 documents for Query_R126:
#   Rank 1: 9384 (Score: 3.9567)
#   Rank 2: 66301 (Score: 2.7180)
#   Rank 3: 69725 (Score: 2.7083)
#   Rank 4: 63280 (Score: 2.3591)
#   Rank 5: 40554 (Score: 2.2381)
#   Rank 6: 80102 (Score: 2.1892)
#   Rank 7: 15228 (Score: 2.0756)
#   Rank 8: 78479 (Score: 1.8912)
#   Rank 9: 78928 (Score: 1.6738)
#   Rank 10: 83225 (Score: 1.6515)
#   Rank 11: 4984 (Score: 1.6417)
#   Rank 12: 60588 (Score: 1.4036)
#
# Processing Query R127 (Title: 'U.S. automobile seat belt')
# Dataset DataSets-1\Dataset127: Found 32 XML files
# Dataset DataSets-1\Dataset127: Parsed 32 documents.
# Final query terms for R127: ['u.s', 'automobile', 'seat', 'belt']
# Saved rankings for R127 to BM25RankingOutputs\BM25IR_R127Ranking.dat
# Top-12 documents for Query_R127:
#   Rank 1: 75738 (Score: 6.4270)
#   Rank 2: 70010 (Score: 5.3890)
#   Rank 3: 67104 (Score: 4.3607)
#   Rank 4: 58487 (Score: 4.1361)
#   Rank 5: 62215 (Score: 3.9395)
#   Rank 6: 10706 (Score: 3.7797)
#   Rank 7: 26026 (Score: 3.7797)
#   Rank 8: 26144 (Score: 3.7797)
#   Rank 9: 40292 (Score: 3.5468)
#   Rank 10: 40234 (Score: 3.1915)
#   Rank 11: 86898 (Score: 1.8676)
#   Rank 12: 62401 (Score: 1.6744)
#
# Processing Query R128 (Title: 'Child labor laws')
# Dataset DataSets-1\Dataset128: Found 51 XML files
# Dataset DataSets-1\Dataset128: Parsed 51 documents.
# Final query terms for R128: ['child', 'labor', 'laws']
# Saved rankings for R128 to BM25RankingOutputs\BM25IR_R128Ranking.dat
# Top-12 documents for Query_R128:
#   Rank 1: 66961 (Score: 6.1719)
#   Rank 2: 64033 (Score: 5.9767)
#   Rank 3: 61170 (Score: 5.9732)
#   Rank 4: 24214 (Score: 5.9033)
#   Rank 5: 70233 (Score: 5.8409)
#   Rank 6: 75201 (Score: 5.7612)
#   Rank 7: 66923 (Score: 5.7143)
#   Rank 8: 27215 (Score: 5.5693)
#   Rank 9: 3740 (Score: 4.6934)
#   Rank 10: 64070 (Score: 4.2959)
#   Rank 11: 60528 (Score: 3.7676)
#   Rank 12: 26085 (Score: 2.7126)
#
# Processing Query R129 (Title: 'Problems illegal aliens U.S.')
# Dataset DataSets-1\Dataset129: Found 72 XML files
# Dataset DataSets-1\Dataset129: Parsed 72 documents.
# Final query terms for R129: ['problems', 'illegal', 'aliens', 'u.s']
# Saved rankings for R129 to BM25RankingOutputs\BM25IR_R129Ranking.dat
# Top-12 documents for Query_R129:
#   Rank 1: 46494 (Score: 6.7438)
#   Rank 2: 35148 (Score: 5.6002)
#   Rank 3: 44081 (Score: 5.4661)
#   Rank 4: 73475 (Score: 5.0769)
#   Rank 5: 43886 (Score: 4.7465)
#   Rank 6: 72899 (Score: 4.4282)
#   Rank 7: 46509 (Score: 4.2039)
#   Rank 8: 83946 (Score: 3.9934)
#   Rank 9: 75714 (Score: 3.9480)
#   Rank 10: 9660 (Score: 3.9000)
#   Rank 11: 75487 (Score: 3.7939)
#   Rank 12: 83958 (Score: 3.4317)
#
# Processing Query R130 (Title: 'College tuition planning')
# Dataset DataSets-1\Dataset130: Found 24 XML files
# Dataset DataSets-1\Dataset130: Parsed 24 documents.
# Final query terms for R130: ['college', 'tuition', 'planning']
# Saved rankings for R130 to BM25RankingOutputs\BM25IR_R130Ranking.dat
# Top-12 documents for Query_R130:
#   Rank 1: 15776 (Score: 10.4314)
#   Rank 2: 60528 (Score: 4.7089)
#   Rank 3: 18235 (Score: 3.9528)
#   Rank 4: 60483 (Score: 3.7334)
#   Rank 5: 70556 (Score: 3.7176)
# Processing Query R134 (Title: 'Crime Statistics Great Britain')
# Dataset DataSets-1\Dataset134: Found 31 XML files
# Dataset DataSets-1\Dataset134: Parsed 31 documents.
# Final query terms for R134: ['crime', 'statistics', 'great', 'britain']
# Saved rankings for R134 to BM25RankingOutputs\BM25IR_R134Ranking.dat
# Top-12 documents for Query_R134:
#   Rank 1: 59659 (Score: 6.6740)
#   Rank 2: 84627 (Score: 3.3281)
#   Rank 3: 75562 (Score: 3.1918)
#   Rank 4: 21172 (Score: 2.9334)
#   Rank 5: 58438 (Score: 2.8531)
#   Rank 6: 46142 (Score: 2.8189)
#   Rank 7: 73397 (Score: 2.8125)
#   Rank 8: 69112 (Score: 2.7977)
#   Rank 9: 14567 (Score: 2.7536)
#   Rank 10: 26253 (Score: 2.7127)
#   Rank 11: 74790 (Score: 2.6924)
#   Rank 12: 43806 (Score: 2.4629)
#
# Processing Query R135 (Title: 'WTO trade debates')
# Dataset DataSets-1\Dataset135: Found 29 XML files
# Dataset DataSets-1\Dataset135: Parsed 29 documents.
# Final query terms for R135: ['wto', 'trade', 'debates']
# Saved rankings for R135 to BM25RankingOutputs\BM25IR_R135Ranking.dat
# Top-12 documents for Query_R135:
#   Rank 1: 52721 (Score: 0.1005)
#   Rank 2: 65311 (Score: 0.1005)
#   Rank 3: 65501 (Score: 0.1005)
#   Rank 4: 80891 (Score: 0.0999)
#   Rank 5: 78998 (Score: 0.0997)
#   Rank 6: 79698 (Score: 0.0997)
#   Rank 7: 46122 (Score: 0.0994)
#   Rank 8: 49229 (Score: 0.0994)
#   Rank 9: 65465 (Score: 0.0993)
#   Rank 10: 66118 (Score: 0.0993)
#   Rank 11: 67275 (Score: 0.0989)
#   Rank 12: 67433 (Score: 0.0989)
#
# Processing Query R136 (Title: 'Substance abuse crime')
# Dataset DataSets-1\Dataset136: Found 46 XML files
# Dataset DataSets-1\Dataset136: Parsed 46 documents.
# Final query terms for R136: ['substance', 'abuse', 'crime']
# Saved rankings for R136 to BM25RankingOutputs\BM25IR_R136Ranking.dat
# Top-12 documents for Query_R136:
#   Rank 1: 35104 (Score: 7.2346)
#   Rank 2: 79605 (Score: 6.7769)
#   Rank 3: 41487 (Score: 6.1660)
#   Rank 4: 8768 (Score: 4.6200)
#   Rank 5: 46422 (Score: 4.3518)
#   Rank 6: 48692 (Score: 4.2250)
#   Rank 7: 83238 (Score: 3.8367)
#   Rank 8: 42907 (Score: 3.7150)
#   Rank 9: 43962 (Score: 3.3533)
#   Rank 10: 58438 (Score: 2.9066)
#   Rank 11: 34428 (Score: 2.7149)
#   Rank 12: 55797 (Score: 2.6589)
#
# Processing Query R137 (Title: 'Sea turtle deaths')
# Dataset DataSets-1\Dataset137: Found 50 XML files
# Dataset DataSets-1\Dataset137: Parsed 50 documents.
# Final query terms for R137: ['sea', 'turtle', 'deaths']
# Saved rankings for R137 to BM25RankingOutputs\BM25IR_R137Ranking.dat
# Top-12 documents for Query_R137:
#   Rank 1: 66879 (Score: 9.9914)
#   Rank 2: 61252 (Score: 6.0440)
#   Rank 3: 46874 (Score: 5.4631)
#   Rank 4: 4650 (Score: 5.1244)
#   Rank 5: 55560 (Score: 5.1201)
#   Rank 6: 85322 (Score: 5.0213)
#   Rank 7: 27297 (Score: 4.3232)
#   Rank 8: 39136 (Score: 4.2963)
#   Rank 9: 53354 (Score: 3.6584)
#   Rank 10: 77179 (Score: 3.4182)
#   Rank 11: 65604 (Score: 3.2873)
#   Rank 12: 13233 (Score: 2.8021)
#
# Processing Query R138 (Title: 'Creutzfeldt-Jakob, mad cow disease')
# Dataset DataSets-1\Dataset138: Found 98 XML files
# Dataset DataSets-1\Dataset138: Parsed 98 documents.
# Final query terms for R138: ['creutzfeldt-jakob', 'mad', 'cow', 'disease']
# Saved rankings for R138 to BM25RankingOutputs\BM25IR_R138Ranking.dat
# Top-12 documents for Query_R138:
#   Rank 1: 77971 (Score: 1.8107)
#   Rank 2: 37732 (Score: 1.5183)
#   Rank 3: 2552 (Score: 1.4882)
#   Rank 4: 20899 (Score: 1.4857)
#   Rank 5: 49872 (Score: 1.4432)
#   Rank 6: 50734 (Score: 1.3717)
#   Rank 7: 40341 (Score: 1.3214)
#   Rank 8: 22407 (Score: 1.3110)
#   Rank 9: 56318 (Score: 1.2807)
#   Rank 10: 65378 (Score: 1.2760)
#   Rank 11: 74775 (Score: 1.2138)
#   Rank 12: 62620 (Score: 1.2130)
#
# Processing Query R139 (Title: 'Pig organ transplants')
# Dataset DataSets-1\Dataset139: Found 21 XML files
# Dataset DataSets-1\Dataset139: Parsed 21 documents.
# Final query terms for R139: ['pig', 'organ', 'transplants']
# Saved rankings for R139 to BM25RankingOutputs\BM25IR_R139Ranking.dat
# Top-12 documents for Query_R139:
#   Rank 1: 71102 (Score: 6.2403)
#   Rank 2: 67204 (Score: 5.4474)
#   Rank 3: 65692 (Score: 3.9490)
#   Rank 4: 54844 (Score: 3.5927)
#   Rank 5: 50076 (Score: 3.1123)
#   Rank 6: 41231 (Score: 2.8839)
#   Rank 7: 79033 (Score: 2.8058)
#   Rank 8: 62586 (Score: 2.6117)
#   Rank 9: 9544 (Score: 2.1658)
#   Rank 10: 58507 (Score: 2.1620)
#   Rank 11: 35853 (Score: 1.7392)
#   Rank 12: 81694 (Score: 1.6678)
#
# Processing Query R140 (Title: 'computer simulation')
# Dataset DataSets-1\Dataset140: Found 59 XML files
# Dataset DataSets-1\Dataset140: Parsed 59 documents.
# Final query terms for R140: ['computer', 'simulation']
# Saved rankings for R140 to BM25RankingOutputs\BM25IR_R140Ranking.dat
# Top-12 documents for Query_R140:
#   Rank 1: 25063 (Score: 5.9080)
#   Rank 2: 44400 (Score: 5.5319)
#   Rank 3: 45396 (Score: 5.4463)
#   Rank 4: 22321 (Score: 5.1752)
#   Rank 5: 58343 (Score: 4.7299)
#   Rank 6: 43139 (Score: 4.6359)
#   Rank 7: 6857 (Score: 4.6043)
#   Rank 8: 35886 (Score: 1.1288)
#   Rank 9: 33779 (Score: 1.1092)
#   Rank 10: 35214 (Score: 1.1092)
#   Rank 11: 57378 (Score: 1.1083)
#   Rank 12: 13885 (Score: 1.0934)
#
# Processing Query R141 (Title: 'Environment National Park')
# Dataset DataSets-1\Dataset141: Found 56 XML files
# Dataset DataSets-1\Dataset141: Parsed 56 documents.
# Final query terms for R141: ['environment', 'national', 'park']
# Saved rankings for R141 to BM25RankingOutputs\BM25IR_R141Ranking.dat
# Top-12 documents for Query_R141:
#   Rank 1: 65284 (Score: 5.3441)
#   Rank 2: 62292 (Score: 4.6695)
#   Rank 3: 60155 (Score: 4.6429)
#   Rank 4: 60221 (Score: 4.4871)
#   Rank 5: 55848 (Score: 3.7863)
#   Rank 6: 58503 (Score: 3.6717)
#   Rank 7: 75561 (Score: 3.2216)
#   Rank 8: 62212 (Score: 2.9613)
#   Rank 9: 62213 (Score: 2.7889)
#   Rank 10: 59351 (Score: 2.5471)
#   Rank 11: 39972 (Score: 2.5089)
#   Rank 12: 17505 (Score: 2.5025)
#
# Processing Query R142 (Title: 'Illiteracy Arab Africa')
# Dataset DataSets-1\Dataset142: Found 28 XML files
# Dataset DataSets-1\Dataset142: Parsed 28 documents.
# Final query terms for R142: ['illiteracy', 'arab', 'africa']
# Saved rankings for R142 to BM25RankingOutputs\BM25IR_R142Ranking.dat
# Top-12 documents for Query_R142:
#   Rank 1: 83869 (Score: 2.9061)
#   Rank 2: 54126 (Score: 2.8049)
#   Rank 3: 68798 (Score: 2.6768)
#   Rank 4: 53188 (Score: 2.6117)
#   Rank 5: 54675 (Score: 2.3979)
#   Rank 6: 34410 (Score: 1.7137)
#   Rank 7: 7397 (Score: 1.5314)
#   Rank 8: 28354 (Score: 1.2748)
#   Rank 9: 54716 (Score: 1.1593)
#   Rank 10: 60740 (Score: 1.1114)
#   Rank 11: 45201 (Score: 1.0505)
#   Rank 12: 6158 (Score: 0.9917)
#
# Processing Query R143 (Title: 'Improving aircraft safety')
# Dataset DataSets-1\Dataset143: Found 52 XML files
# Dataset DataSets-1\Dataset143: Parsed 52 documents.
# Final query terms for R143: ['improving', 'aircraft', 'safety']
# Saved rankings for R143 to BM25RankingOutputs\BM25IR_R143Ranking.dat
# Top-12 documents for Query_R143:
#   Rank 1: 44232 (Score: 1.7035)
#   Rank 2: 30864 (Score: 1.6454)
#   Rank 3: 37657 (Score: 1.5438)
#   Rank 4: 75564 (Score: 1.5224)
#   Rank 5: 28717 (Score: 1.5117)
#   Rank 6: 7041 (Score: 1.4912)
#   Rank 7: 74605 (Score: 1.4870)
#   Rank 8: 72134 (Score: 1.4501)
#   Rank 9: 78628 (Score: 1.4467)
#   Rank 10: 77430 (Score: 1.4406)
#   Rank 11: 77431 (Score: 1.4396)
#   Rank 12: 3666 (Score: 1.4061)
#
# Processing Query R144 (Title: 'Mountain climbing deaths')
# Dataset DataSets-1\Dataset144: Found 50 XML files
# Dataset DataSets-1\Dataset144: Parsed 50 documents.
# Final query terms for R144: ['mountain', 'climbing', 'deaths']
# Saved rankings for R144 to BM25RankingOutputs\BM25IR_R144Ranking.dat
# Top-12 documents for Query_R144:
#   Rank 1: 69511 (Score: 6.0679)
#   Rank 2: 36318 (Score: 5.5083)
#   Rank 3: 19626 (Score: 5.4327)
#   Rank 4: 35258 (Score: 5.3618)
#   Rank 5: 3364 (Score: 5.0985)
#   Rank 6: 12579 (Score: 4.1829)
#   Rank 7: 43899 (Score: 4.1760)
#   Rank 8: 13135 (Score: 3.7945)
#   Rank 9: 24598 (Score: 3.7411)
#   Rank 10: 49230 (Score: 3.5589)
#   Rank 11: 7359 (Score: 3.2213)
#   Rank 12: 12855 (Score: 3.0512)
#
# Processing Query R145 (Title: 'Airline passenger disruptions')
# Dataset DataSets-1\Dataset145: Found 95 XML files
# Dataset DataSets-1\Dataset145: Parsed 95 documents.
# Final query terms for R145: ['airline', 'passenger', 'disruptions']
# Saved rankings for R145 to BM25RankingOutputs\BM25IR_R145Ranking.dat
# Top-12 documents for Query_R145:
#   Rank 1: 54291 (Score: 5.8312)
#   Rank 2: 4300 (Score: 5.4365)
#   Rank 3: 50193 (Score: 5.0733)
#   Rank 4: 41447 (Score: 4.7455)
#   Rank 5: 3781 (Score: 4.4675)
#   Rank 6: 79732 (Score: 4.2746)
#   Rank 7: 41461 (Score: 4.1346)
#   Rank 8: 40278 (Score: 3.8261)
#   Rank 9: 32232 (Score: 3.6765)
#   Rank 10: 14673 (Score: 3.5517)
#   Rank 11: 21077 (Score: 3.5467)
#   Rank 12: 68048 (Score: 3.0275)
#
# Processing Query R146 (Title: 'Germ warfare')
# Dataset DataSets-1\Dataset146: Found 32 XML files
# Dataset DataSets-1\Dataset146: Parsed 32 documents.
# Final query terms for R146: ['germ', 'warfare']
# Saved rankings for R146 to BM25RankingOutputs\BM25IR_R146Ranking.dat
# Top-12 documents for Query_R146:
#   Rank 1: 12035 (Score: 5.1247)
#   Rank 2: 23687 (Score: 4.4864)
#   Rank 3: 72072 (Score: 4.2786)
#   Rank 4: 49904 (Score: 4.1426)
#   Rank 5: 38821 (Score: 3.6687)
#   Rank 6: 24287 (Score: 3.3332)
#   Rank 7: 12196 (Score: 2.9618)
#   Rank 8: 54065 (Score: 2.8187)
#   Rank 9: 12396 (Score: 2.6595)
#   Rank 10: 11944 (Score: 0.0000)
#   Rank 11: 12476 (Score: 0.0000)
#   Rank 12: 14541 (Score: 0.0000)
#
# Processing Query R147 (Title: 'Natural gas vehicles')
# Dataset DataSets-1\Dataset147: Found 62 XML files
# Dataset DataSets-1\Dataset147: Parsed 62 documents.
# Final query terms for R147: ['natural', 'gas', 'vehicles']
# Saved rankings for R147 to BM25RankingOutputs\BM25IR_R147Ranking.dat
# Top-12 documents for Query_R147:
#   Rank 1: 27441 (Score: 4.1581)
#   Rank 2: 64153 (Score: 4.0947)
#   Rank 3: 34675 (Score: 3.8801)
#   Rank 4: 73146 (Score: 3.7367)
#   Rank 5: 27911 (Score: 3.5644)
#   Rank 6: 56691 (Score: 3.4056)
#   Rank 7: 41481 (Score: 3.2694)
#   Rank 8: 59813 (Score: 3.2303)
#   Rank 9: 76089 (Score: 3.1714)
#   Rank 10: 76092 (Score: 3.1714)
#   Rank 11: 75754 (Score: 3.1543)
#   Rank 12: 81325 (Score: 3.1519)
#
# Processing Query R148 (Title: 'NAFTA')
# Dataset DataSets-1\Dataset148: Found 33 XML files
# Dataset DataSets-1\Dataset148: Parsed 33 documents.
# Final query terms for R148: ['nafta']
# Saved rankings for R148 to BM25RankingOutputs\BM25IR_R148Ranking.dat
# Top-12 documents for Query_R148:
#   Rank 1: 84829 (Score: 1.3039)
#   Rank 2: 9133 (Score: 1.2617)
#   Rank 3: 8622 (Score: 1.2602)
#   Rank 4: 58009 (Score: 1.2576)
#   Rank 5: 24044 (Score: 1.2548)
#   Rank 6: 51453 (Score: 1.2045)
#   Rank 7: 31619 (Score: 1.1795)
#   Rank 8: 60293 (Score: 1.1421)
#   Rank 9: 51260 (Score: 1.1172)
#   Rank 10: 52489 (Score: 1.1124)
#   Rank 11: 75205 (Score: 1.0904)
#   Rank 12: 85344 (Score: 1.0459)
#
# Processing Query R149 (Title: 'Aid to handicapped people')
# Dataset DataSets-1\Dataset149: Found 26 XML files
# Dataset DataSets-1\Dataset149: Parsed 26 documents.
# Final query terms for R149: ['aid', 'handicapped', 'people']
# Saved rankings for R149 to BM25RankingOutputs\BM25IR_R149Ranking.dat
# Top-12 documents for Query_R149:
#   Rank 1: 41538 (Score: 5.4016)
#   Rank 2: 39661 (Score: 5.0645)
#   Rank 3: 39926 (Score: 4.7953)
#   Rank 4: 25529 (Score: 4.6205)
#   Rank 5: 17390 (Score: 3.7525)
#   Rank 6: 17360 (Score: 3.6280)
#   Rank 7: 32400 (Score: 3.4012)
#   Rank 8: 62392 (Score: 3.2762)
#   Rank 9: 3936 (Score: 3.2548)
#   Rank 10: 14196 (Score: 2.9586)
#   Rank 11: 30390 (Score: 2.3214)
#   Rank 12: 16941 (Score: 2.2446)
#
# Processing Query R150 (Title: 'Drive-by shootings')
# Dataset DataSets-1\Dataset150: Found 51 XML files
# Dataset DataSets-1\Dataset150: Parsed 51 documents.
# Final query terms for R150: ['drive-by', 'shootings']
# Saved rankings for R150 to BM25RankingOutputs\BM25IR_R150Ranking.dat
# Top-12 documents for Query_R150:
#   Rank 1: 53361 (Score: 9.9318)
#   Rank 2: 85411 (Score: 5.4364)
#   Rank 3: 54538 (Score: 4.4757)
#   Rank 4: 19420 (Score: 4.2305)
#   Rank 5: 19411 (Score: 3.9838)
#   Rank 6: 19409 (Score: 3.7015)
#   Rank 7: 19885 (Score: 3.5393)
#   Rank 8: 19408 (Score: 0.0000)
#   Rank 9: 19417 (Score: 0.0000)
#   Rank 10: 23349 (Score: 0.0000)
#   Rank 11: 23361 (Score: 0.0000)
#   Rank 12: 26648 (Score: 0.0000)
#
# Top-12 documents for all queries saved to BM25IR_Top12_Results.xlsx
#
# BM25IR System run complete.
